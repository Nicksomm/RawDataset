# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %%
pd.read_csv('Trump vs. Biden - Sheet1.csv')
# Out:
#                    2016 election     Unnamed: 1 2020 Election  \
# 0                Hillary Clinton   Donal Trump      Joe Biden
# 1                             227           304           306
# 2                             48%           46%           51%
# 3                      65,853,514    62,984,828    79,271,864
# 4                             NaN           NaN           NaN
# 5                    Demogrpahics           NaN           NaN
# 6                             NaN         Trump         Biden
# 7               Male48% of voters           53%           45%
# 8                       Female52%            42            57
# 9                             NaN           NaN           NaN
# 10                            NaN           NaN           NaN
# 11                            NaN        Trump          Biden
# 12             White67% of voters            58            41
# 13                       Black13%            12            87
# ...

# %%
df.head(10)
# Out:
#       2016 election     Unnamed: 1 2020 Election    Unnamed: 3
# 0   Hillary Clinton   Donal Trump      Joe Biden  Donald Trump
# 1                227           304           306           232
# 2                48%           46%           51%           47%
# 3         65,853,514    62,984,828    79,271,864    73,464,544
# 4                NaN           NaN           NaN           NaN
# 5       Demogrpahics           NaN           NaN           NaN
# 6                NaN         Trump         Biden           NaN
# 7  Male48% of voters           53%           45%           NaN
# 8          Female52%            42            57           NaN
# 9                NaN           NaN           NaN           NaN

# %%
df.tail(10)
# Out:
#                 2016 election  Unnamed: 1 2020 Election  \
# 29            Yes 7% of voters         27            64
# 30                      No 93%         48            51
# 31                         NaN        NaN           NaN
# 32  Under $50,00035% of voters         44            55
# 33          $50,000-$99,99939%         42            57
# 34         $100,000 or more26%         54            42
# 35                         NaN        NaN           NaN
# 36  Better today 41% of voters         72            26
# 37             Worse today 20%         20            77
# 38          About the same 39%         34            65
#
#                                 Unnamed: 3
# 29  gay, lesbian, bisexual or transgender?
# 30                                     NaN
# 31                                     NaN
# 32                       Total income 2019
# 33                                     NaN
# 34                                     NaN
# ...

# %%
df.sample(10)
# Out:
#         2016 election   Unnamed: 1 2020 Election  Unnamed: 3
# 8            Female52%          42            57         NaN
# 21      65 or over 22%          52            47         NaN
# 5         Demogrpahics         NaN           NaN         NaN
# 33  $50,000-$99,99939%          42            57         NaN
# 14  Hispanic/Latino13%          32            65         NaN
# 25                 NaN         NaN           NaN         NaN
# 11                 NaN      Trump          Biden         NaN
# 37     Worse today 20%          20            77         NaN
# 20           45-64 38%          50            49         NaN
# 3           65,853,514  62,984,828    79,271,864  73,464,544

# %%
df.shape
# Out:
# (39, 4)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
